# %% [markdown]
# # Baking Strategy

# %%
## Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import datetime

from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
# Read in and examine the data set

transactions = pd.read_csv(r'C:\Users\jbean\Dropbox\Other\Python\Bakery\transaction_data.csv')

transactions.head()

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21293 entries, 0 to 21292
# Data columns (total 4 columns):
# Date           21293 non-null object
# Time           21293 non-null object
# Transaction    21293 non-null int64
# Item           21293 non-null object
# dtypes: int64(1), object(3)
# memory usage: 665.5+ KB

# %% [markdown]
# # Data Cleaning and Manipulation

# %%
# Convert date to datetime object
transactions['Date'] = pd.to_datetime(transactions['Date'], format='%m/%d/%Y')

# %%
# Convert time column to datetime; add hour and minute column; drop Time column

transactions['Time'] = pd.to_datetime(transactions['Time'])

transactions['hour'] = transactions.Time.dt.hour
transactions['minute'] = transactions.Time.dt.minute

transactions = transactions.drop(['Time'], axis=1)

# %%
# Filter out missing values

transactions = transactions[transactions.Item != 'NONE']

# %%
def time_of_day(hour):
    """
    Determines whether a purchase was made in the morning, afternoon, or evening.
    """
    
    if hour < 12:
        
        return 'morning'
    
    elif hour < 17:
        
        return 'afternoon'
    
    else:
        
        return 'evening'

# %%
# Apply time of day function to 'hour' column

transactions['time_of_day'] = transactions.hour.apply(time_of_day)

# %%
# Add a day of week variable and a second classifier of weekday or weekend

from datetime import date
import calendar

transactions['day_of_week'] = [calendar.day_name[i.weekday()] for i in transactions['Date']]

transactions['day_type'] = ['weekend' if (i == 'Sunday') | (i == 'Saturday') else 'weekday' for i in 
                                                                            transactions['day_of_week']]

# %%
# Add an item count variable equal to one for future groupby operations

transactions['item_count'] = 1

# %% [markdown]
# # Data Exploration

# %%
# Look at the average number of items purchased...

avg_items = transactions.groupby(by='Transaction')['Item'].count().mean()

print('The average number of items bought by a customer is: %.2f items' %avg_items)
# Out:
# The average number of items bought by a customer is: 2.17 items

# %%
# ...and how that varies by time of day

single_transaction = pd.DataFrame(transactions.groupby(by='Transaction')['item_count'].sum())

single_transaction = single_transaction.merge(transactions[['hour','minute','time_of_day','Date', 'Transaction']]\
                                              .drop_duplicates('Transaction'), left_on=single_transaction.index, 
                                              right_on='Transaction', how='left', copy=False)

print('The average number of items by time of day: \n{0}'.format(
    single_transaction.groupby(by='time_of_day')['item_count'].mean()))
# Out:
# The average number of items by time of day:
# time_of_day
# afternoon    2.273335
# evening      1.956044
# morning      2.048257
# Name: item_count, dtype: float64

# %%
# Find the frequency of each item purchased and by time of day

item_frequencies_all = transactions.Item.value_counts()
item_frequencies_morning = transactions[transactions.time_of_day == 'morning'].Item.value_counts()
item_frequencies_afternoon = transactions[transactions.time_of_day == 'afternoon'].Item.value_counts()
item_frequencies_evening = transactions[transactions.time_of_day == 'evening'].Item.value_counts()

# %%
# Plot the frequency of purchase for each item

import plotly.plotly as py
import plotly.graph_objs as go

button_layer_1_height = 1.12
button_layer_2_height = 1.065

item_threshold_all = 100
item_threshold_other = 50

trace_all = go.Bar(
            x=item_frequencies_all[item_frequencies_all > item_threshold_all].index,
            y=item_frequencies_all[item_frequencies_all > item_threshold_all].values,
            visible=True,
            name='All'
    )

trace_morning = go.Bar(
            x=item_frequencies_morning[item_frequencies_morning > item_threshold_other].index,
            y=item_frequencies_morning[item_frequencies_morning > item_threshold_other].values,
            visible=False,
            name='Morning'
    )

trace_afternoon = go.Bar(
            x=item_frequencies_afternoon[item_frequencies_afternoon > item_threshold_other].index,
            y=item_frequencies_afternoon[item_frequencies_afternoon > item_threshold_other].values,
            visible=False,
            name='Afternoon'
    )

trace_evening = go.Bar(
            x=item_frequencies_evening[item_frequencies_evening > 10].index,
            y=item_frequencies_evening[item_frequencies_evening > 10].values,
            visible=False,
            name='Evening'
    )

data = [trace_all, trace_morning, trace_afternoon, trace_evening]

updatemenus = list([
    
    dict(
         buttons=list([   
            dict(label = 'All',
                 method = 'update',
                 args = [{'visible': [True, False, False, False]},
                         {'title': 'All Day'}]),
             
            dict(label = 'Morning',
                 method = 'update',
                 args = [{'visible': [False, True, False, False]},
                         {'title': 'Morning'}]),
             
            dict(label = 'Afternoon',
                 method = 'update',
                 args = [{'visible': [False, False, True, False]},
                         {'title': 'Afternoon'}]),
             
            dict(label = 'Evening',
                 method = 'update',
                 args = [{'visible': [False, False, False, True]},
                         {'title': 'Evening'}])
        ]),
        type='buttons',
        direction = 'right',
        pad = {'r': 10, 't': 10},
        showactive = True,
        x = 0.3,
        xanchor = 'left',
        y = button_layer_1_height,
        yanchor = 'top' )
])
                
layout = dict(title='Bakery Transactions by Time of Day', showlegend=False,
              updatemenus=updatemenus)
                
fig = dict(data=data, layout=layout)

py.iplot(fig, filename='frequencies-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/138.embed" height="525px" width="100%"></iframe>

# %%
# Sales trend by date

grouped_by_date = pd.DataFrame(transactions.groupby(by='Date')['item_count'].sum())

# %%
grouped_by_date.head()
# Out:
#             item_count
# Date
# 2016-10-30         170
# 2016-10-31         199
# 2016-11-01         150
# 2016-11-02         164
# 2016-11-03         189

# %%
from plotly.grid_objs import Grid, Column
import plotly.figure_factory as ff

# Create a plot.ly-friendly table for minutes per day

table = ff.create_table(grouped_by_date)
py.iplot(table, filename='sales_per_day_bakery')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/144.embed" height="4850px" width="100%"></iframe>

# %%
# Formatting for the plot.ly chart based on code adapted from an example in their gallery

number_of_items_sold = list(grouped_by_date['item_count'])

my_columns = []

for k in range(len(grouped_by_date.index) - 1):
    
    my_columns.append(Column(grouped_by_date.index[:k + 1], 'x{}'.format(k + 1)))   
    my_columns.append(Column(number_of_items_sold[:k + 1], 'y{}'.format(k + 1)))
    
grid = Grid(my_columns)
py.grid_ops.upload(grid, 'items_sold', auto_open=False)
# Out:
# 'https://plot.ly/~jbean01/146/'

# %%
data=[dict(type='scatter',
           xsrc=grid.get_column_reference('x1'),
           ysrc= grid.get_column_reference('y1'),
           name='Bakery',
           mode='lines',
           line=dict(color= 'rgb(0, 153, 255)'),
           fill='tozeroy',
           fillcolor='rgba(153, 204, 255, 0.5)')]

axis=dict(ticklen=4,
          mirror=True,
          zeroline=False,
          showline=True,
          autorange=False,
          showgrid=False)

layout = dict(title='Sales per Day',
              font=dict(family='Balto'),
              showlegend=False,
              autosize=False,
              width=800,
              height=400,
              xaxis=dict(axis, **{'nticks':12, 'tickangle':-45,
                                  'range': [min(grouped_by_date.index),
                                            max(grouped_by_date.index)]}),
              yaxis=dict(axis, **{'title': 'Items Sold', 'range':[0,max(grouped_by_date.item_count)+5]}),
              updatemenus=[dict(type='buttons',
                                showactive=False,
                                y=1,
                                x=1.1,
                                xanchor='right',
                                yanchor='top',
                                pad=dict(t=0, r=10),
                                buttons=[dict(label='Play',
                                              method='animate',
                                              args=[None, dict(frame=dict(duration=50, redraw=False), 
                                                               transition=dict(duration=0),
                                                               fromcurrent=True,
                                                               mode='immediate')])])])

frames=[{'data':[{'xsrc': grid.get_column_reference('x{}'.format(k + 1)),
                  'ysrc': grid.get_column_reference('y{}'.format(k + 1))}],
         'traces': [0]
        } for k in range(len(grouped_by_date.index) - 1)]

fig=dict(data=data, layout=layout, frames=frames)
py.icreate_animations(fig, 'Sales-per-Day-Bakery')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/147.embed" height="400px" width="800px"></iframe>

# %%
weekday_sales = pd.DataFrame(transactions[transactions.day_type == 'weekday'].groupby(by='Date')['item_count'].sum())
weekend_sales = pd.DataFrame(transactions[transactions.day_type == 'weekend'].groupby(by='Date')['item_count'].sum())

# %%
weekday_sales.item_count.min()
# Out:
# 47

# %%
# Histogram of items sold by type of day

trace_weekday = go.Histogram(
    x=weekday_sales[weekday_sales.item_count > 50].item_count,
    opacity=0.75,
    name = 'weekday',
)

trace_weekend = go.Histogram(
    x=weekend_sales[weekend_sales.item_count > 1].item_count,
    opacity=0.75,
    name = 'weekend',
    nbinsx = 12
)

data = [trace_weekday, trace_weekend]
layout = go.Layout(title = 'Distribution of Sales by Weekday / Weekend',
                   xaxis=dict(title='Number of Items Sold'),
                   yaxis=dict(title='Frequency of Sales'),
                   barmode='overlay')

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='day-type-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/148.embed" height="525px" width="100%"></iframe>

# %%
# Find the number of minutes played per day of week

merged_sales_per_day = grouped_by_date.merge(transactions[['day_of_week', 'Date']], left_index=True, right_on='Date',
                                                        how='left', validate='1:m')

merged_sales_per_day = merged_sales_per_day[~merged_sales_per_day.index.duplicated(keep='first')]

days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

sales_per_day = []

for day in days:
    
    df_days = merged_sales_per_day[merged_sales_per_day.day_of_week == day]
    
    sales_per_day.append(list(df_days['item_count']))

# %%
traces = []

for i, j in enumerate(days):
    
    trace = go.Box(
    y=sales_per_day[i],
    name = j
    )
    traces.append(trace)

data = traces

layout = go.Layout(title='Sales per Day',
                  xaxis = dict(title = 'Day of Week'),
                  yaxis = dict(title = 'Number of Items Sold'))

fig = go.Figure(data = data, layout = layout)

py.iplot(fig, filename='Sales-per-day-boxplot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/156.embed" height="525px" width="100%"></iframe>

# %%
group_by_day_and_time = transactions.groupby(by=['day_of_week','time_of_day'])['item_count'].sum()

# %%
group_by_day_and_time = pd.DataFrame(group_by_day_and_time).reset_index()

# %%
group_by_day_and_time
# Out:
#    day_of_week time_of_day  item_count
# 0       Friday   afternoon        1705
# 1       Friday     evening          70
# 2       Friday     morning        1349
# 3       Monday   afternoon        1365
# 4       Monday     evening          44
# 5       Monday     morning         915
# 6     Saturday   afternoon        2464
# 7     Saturday     evening         153
# 8     Saturday     morning        1988
# 9       Sunday   afternoon        1832
# 10      Sunday     evening          21
# 11      Sunday     morning        1242
# 12    Thursday   afternoon        1482
# 13    Thursday     evening          85
# 14    Thursday     morning        1079
# 15     Tuesday   afternoon        1383
# 16     Tuesday     evening          86
# 17     Tuesday     morning         923
# 18   Wednesday   afternoon        1338
# 19   Wednesday     evening          75
# 20   Wednesday     morning         908

# %%
group_by_day_and_time[group_by_day_and_time.time_of_day == 'morning'].item_count
# Out:
# 2     1349
# 5      915
# 8     1988
# 11    1242
# 14    1079
# 17     923
# 20     908
# Name: item_count, dtype: int64

# %%
trace_morning = go.Bar(
    y = group_by_day_and_time[group_by_day_and_time.time_of_day == 'morning'].item_count,
    x = group_by_day_and_time[group_by_day_and_time.time_of_day == 'morning'].day_of_week,
    name = "morning",
    opacity=0.6
)

trace_afternoon = go.Bar(
    y = group_by_day_and_time[group_by_day_and_time.time_of_day == 'afternoon'].item_count,
    x = group_by_day_and_time[group_by_day_and_time.time_of_day == 'afternoon'].day_of_week,
    name = "afternoon",
    opacity=0.6
)

trace_evening = go.Bar(
   y = group_by_day_and_time[group_by_day_and_time.time_of_day == 'evening'].item_count,
    x = group_by_day_and_time[group_by_day_and_time.time_of_day == 'evening'].day_of_week,
    name = "evening",
    opacity=0.6
)
    
data = [trace_morning, trace_afternoon, trace_evening]

py.iplot(data, filename='sales-by-day-time')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/158.embed" height="525px" width="100%"></iframe>

# %%
sales_by_hour = pd.DataFrame(
                transactions[(transactions.hour > 1) & (transactions.hour < 21)].groupby(by='hour')['item_count'].sum())

# %%
sales_by_hour
# Out:
#       item_count
# hour
# 7             24
# 8            645
# 9           1966
# 10          2666
# 11          3102
# 12          2854
# 13          2617
# 14          2640
# 15          2115
# 16          1343
# 17           368
# 18            82
# 19            48
# 20            22

# %%
trace = go.Scatter(x=list(sales_by_hour.index),
                   y=list(sales_by_hour.item_count),
                   fill = 'tozeroy',
                   fillcolor = 'lightblue')

data = [trace]

layout = dict(
    title='Total volume of sales by hour',
    yaxis = dict( title = 'Volume of Item Sales'),
    xaxis=dict( title = 'Hour',
        rangeselector=dict(
            buttons=list([
                dict(count = 12,
                     label='Morning',
                     step='hour',
                     stepmode='backward'),
                dict(count = 8,
                     label='Afternoon',
                     step='hour',
                     stepmode='backward'),
                dict(count = 4,
                    label='Evening',
                    step='hour',
                    stepmode='backward'),
                dict(step='all')
            ]),
            visible = True
        ),
        rangeslider=dict(
            visible = True
        )
    )
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = 'sales-by-hour')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jbean01/182.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Apriori Algorithm, Method 1

# %%
# Create a list of lists that is conducive to the format expected from apyori

list_of_lists = []

for transaction in list(set(transactions.Transaction)):
    
    df = transactions[transactions.Transaction == transaction]
    values = df.Item.values
    
    list_of_lists.append(list(values))

# %%
# Create a list of association rules

from apyori import apriori

association_rules = apriori(list_of_lists, min_confidence = 0, min_support = 0.005, min_length=2)  
association_results = list(association_rules)

# %%
def apriori_results(min_confidence=0, min_support=0.005, sort_by_value = 'lift', min_length =None,
                    time_of_day=None, day_of_week = None, df=transactions):
    
    """
    Takes in a data frame, filters it by time of day, calculates the results of the Apriori algorithm,
    and returns a data frame sorted by lift.
    """
    
    from apyori import apriori
    
    if time_of_day != None:
        
        df = df[df.time_of_day == time_of_day]
        
    if day_of_week:
        
        df = df[df.day_type == day_of_week]
        
    list_of_lists = []

    for transaction in list(set(df.Transaction)):

        df_t = df[df.Transaction == transaction]
        values = df_t.Item.values

        list_of_lists.append(list(values))

    if min_length is not None:
        
        list_of_lists = [i for i in list_of_lists if len(i) >= min_length]
        
    association_rules = apriori(list_of_lists, min_confidence = min_confidence, min_support = min_support)  
    association_results = list(association_rules)

    item_1 = []
    item_2 = []
    support = []
    confidence = []
    lift = []

    for item in association_results:

        pair = item[0] 
        items = [x for x in pair]
        
        if min_length is not None:
            
            if len(items) < min_length:

                continue

            else:

                item_1.append(items[0])

            #try:

                item_2.append(items[1])

            #except:

            #    item_2.append('None')
            
        else:
            
            item_1.append(items[0])

            try:

                item_2.append(items[1])

            except:

                item_2.append('None')

        support.append(item[1])

        confidence.append(item[2][0][2])
        lift.append(item[2][0][3])

    df_apriori = pd.DataFrame({'item_1':item_1, 'item_2':item_2, 'support':support,'confidence':confidence,'lift':lift})
    
    df_apriori = df_apriori.sort_values(by=sort_by_value, ascending=False)
    
    return df_apriori

# %%
all_day_results = apriori_results()

# %%
print(all_day_results)
# Out:
#                 item_1          item_2   support  confidence      lift
# 87            Sandwich            Coke  0.005177    0.266304  3.706722
# 89               Juice         Cookies  0.006128    0.112621  2.920442
# 99            Sandwich            Soup  0.005494    0.076471  2.220227
# 111             Coffee   Hot chocolate  0.006867    0.125483  2.151618
# 93            Sandwich           Juice  0.005811    0.150685  2.097401
# 88       Hot chocolate         Cookies  0.006022    0.110680  1.897794
# 60       Hot chocolate            Cake  0.011410    0.109868  1.883874
# 102                Tea            Soup  0.009086    0.263804  1.849557
# 61               Juice            Cake  0.007079    0.068159  1.767458
# 95              Pastry       Medialuna  0.009192    0.148718  1.727135
# 101                Tea           Scone  0.008347    0.241590  1.693816
# 73    Keeping It Local          Coffee  0.005388    0.011263  1.692169
# 64                 Tea            Cake  0.023772    0.228891  1.604781
# 85              Coffee           Toast  0.023666    0.049470  1.472431
# 108             Pastry          Coffee  0.011199    0.124413  1.444872
# 100           Sandwich             Tea  0.014369    0.200000  1.402222
# 103                Tea           Toast  0.006445    0.045185  1.344899
# 78               Salad          Coffee  0.006550    0.013693  1.309094
# 94                 Tea           Juice  0.007184    0.186301  1.306180
# 39                 Tea       Alfajores  0.006762    0.186047  1.304393
# 59             Cookies            Cake  0.007290    0.070193  1.290057
# 112                Tea          Coffee  0.010037    0.183398  1.285822
# 90                 Tea         Cookies  0.009826    0.180583  1.266084
# 82              Coffee  Spanish Brunch  0.010882    0.022747  1.251766
# 107             Coffee           Bread  0.006762    0.075117  1.215361
# 34              The Nomad            None  0.006092    0.006092  1.000000
# 33                    Tea            None  0.169778    0.169778  1.000000
# 29              Smoothies            None  0.010808    0.010808  1.000000
# 37               Truffles            None  0.029672    0.029672  1.000000
# 36                  Toast            None  0.022401    0.022401  1.000000
# 31         Spanish Brunch            None  0.024366    0.024366  1.000000
# 30                   Soup            None  0.060719    0.060719  1.000000
# 38         Vegan mincepie            None  0.005895    0.005895  1.000000
# 40              Alfajores            Cake  0.006092    0.136564  0.998525
# 91                 Coffee            Soup  0.027707    0.060256  0.992378
# 73                   Soup            Cake  0.008057    0.058908  0.970172
# 116                Coffee           Bread  0.013559    0.445161  0.968131
# 125              Sandwich          Coffee  0.008057    0.112022  0.966236
# 118                Coffee           Bread  0.005109    0.056769  0.962984
# 69                 Muffin            Cake  0.005306    0.038793  0.958340
# 102                   Tea   Hot chocolate  0.009825    0.159744  0.940902
# 62                Brownie            Cake  0.006288    0.128514  0.939667
# 39              Alfajores           Bread  0.012576    0.281938  0.922098
# 101              Sandwich   Hot chocolate  0.006485    0.105431  0.909390
# 75           Chicken Stew          Coffee  0.009432    0.410256  0.892220
# 85          Mineral water          Coffee  0.008253    0.017949  0.837991
# 128              Sandwich          Coffee  0.008646    0.138801  0.817546
# 70                 Pastry            Cake  0.005109    0.037356  0.815907
# 43                Brownie           Bread  0.012183    0.039846  0.814358
# 56                  Scone           Bread  0.010218    0.033419  0.794717
# 52                 Muffin           Bread  0.009825    0.032134  0.793827
# 108                   Tea          Pastry  0.006092    0.133047  0.783654
# 71               Sandwich            Cake  0.011987    0.087644  0.755964
# 47                  Bread         Cookies  0.013559    0.044344  0.752230
# 54               Sandwich           Bread  0.026528    0.086761  0.748350
# 93                    Tea          Coffee  0.057182    0.124359  0.732480
# 44                  Bread            Cake  0.030458    0.099614  0.728359
# 45           Chicken Stew           Bread  0.005109    0.016710  0.726792
# 61               Truffles           Bread  0.006485    0.021208  0.714759
# 55           Scandinavian           Bread  0.005699    0.018638  0.713131
# 58                  Bread  Spanish Brunch  0.005306    0.017352  0.712139
# 96                 Coffee        Truffles  0.009629    0.020940  0.705725
# 77                 Coffee            Coke  0.008843    0.019231  0.699038
# 48          Hot chocolate           Bread  0.012380    0.040488  0.658293
# 51                  Bread       Medialuna  0.007467    0.024422  0.654113
# 59                    Tea           Bread  0.033798    0.110540  0.651085
# 57                   Soup           Bread  0.011987    0.039203  0.645646
# 46                 Coffee           Bread  0.089998    0.294344  0.640136
# 50                  Juice           Bread  0.008057    0.026350  0.606757
# 122                   Tea          Coffee  0.009039    0.100437  0.591577

# %%
evening_results = apriori_results(time_of_day='evening')

# %%
weekday_results = apriori_results(day_of_week = 'weekday')

# %%
weekend_results = apriori_results(day_of_week = 'weekend')

# %%
weekday_morning_results = apriori_results(day_of_week = 'weekday', time_of_day = 'morning')

# %%
weekday_morning_results
# Out:
#               item_1         item_2   support  confidence      lift
# 59             Juice        Cookies  0.007175    0.133803  4.320852
# 69          Sandwich            Tea  0.007175    0.316667  2.636897
# 73            Coffee          Bread  0.006042    0.067511  0.907451
# 26         Alfajores          Bread  0.007931    0.313433  0.904107
# 42            Coffee        Brownie  0.010952    0.475410  0.897921
# 48            Coffee  Hot chocolate  0.021148    0.039943  0.888814
# 37            Pastry          Bread  0.043051    0.124183  0.883969
# 38          Sandwich          Bread  0.006798    0.019608  0.865359
# 49            Coffee            Jam  0.007175    0.013552  0.854426
# 28           Brownie          Bread  0.006798    0.019608  0.851173
# 35             Bread      Medialuna  0.021148    0.061002  0.819968
# 39      Scandinavian          Bread  0.006042    0.017429  0.809693
# 55          Sandwich         Coffee  0.009441    0.017832  0.786971
# 32     Hot chocolate          Bread  0.011707    0.033769  0.751433
# 66               Tea      Medialuna  0.006420    0.086294  0.718577
# 41             Toast          Bread  0.013973    0.040305  0.716293
# 34             Juice          Bread  0.007553    0.021786  0.703544
# 60            Pastry        Cookies  0.005287    0.098592  0.701802
# 29             Bread           Cake  0.013218    0.038126  0.668600
# 56               Tea         Coffee  0.041918    0.079173  0.659274
# 79               Tea         Pastry  0.006042    0.073394  0.611159
# 40               Tea          Bread  0.023036    0.066449  0.553322
# 75               Tea         Coffee  0.005665    0.063291  0.527028
# 36            Muffin          Bread  0.005665    0.016340  0.521301
# 30            Coffee          Bread  0.089502    0.258170  0.487613
# 47            Coffee     Farm House  0.007553    0.014265  0.290574

# %%
weekday_afternoon_results = apriori_results(day_of_week = 'weekday', time_of_day = 'afternoon')

# %%
weekday_afternoon_results[:20]
# Out:
#             item_1          item_2   support  confidence      lift
# 97   Mineral water        Sandwich  0.006917    0.333333  2.777778
# 88        Sandwich            Coke  0.009925    0.326733  2.722772
# 90           Juice         Cookies  0.006617    0.100000  2.427007
# 113         Coffee   Hot chocolate  0.008120    0.122727  2.229881
# 89   Hot chocolate         Cookies  0.006917    0.104545  1.899528
# 94        Sandwich           Juice  0.009323    0.226277  1.885645
# 105            Tea  Spanish Brunch  0.005414    0.315789  1.868327
# 102       Sandwich        Truffles  0.006617    0.055138  1.851852
# 62   Hot chocolate            Cake  0.012632    0.100719  1.830011
# 109         Pastry          Coffee  0.007218    0.086643  1.823333
# 63           Juice            Cake  0.009323    0.074341  1.804250
# 104            Tea            Soup  0.020150    0.274590  1.624577
# 103            Tea           Scone  0.008421    0.274510  1.624102
# 117       Sandwich          Coffee  0.006917    0.112745  1.536383
# 86          Coffee           Toast  0.016842    0.036770  1.528234
# 59             Tea         Brownie  0.010526    0.251799  1.489733
# 106            Tea           Toast  0.006015    0.035587  1.479093
# 79           Salad          Coffee  0.011729    0.025607  1.419074
# 66             Tea            Cake  0.030075    0.239808  1.418794
# 91             Tea         Cookies  0.015639    0.236364  1.398415

# %% [markdown]
# # Apriori Algorithm, Method 2

# %%
def apriori_results_method_2(df = transactions, min_support = 0.005, time_of_day = None, day_of_week = None,
                            min_threshold = 1, metric = 'lift'):
    
    """
    Takes in a data frame and returns the results of the Apriori algorithm using the mlxtend Python package.
    """
    
    from mlxtend.frequent_patterns import apriori
    from mlxtend.frequent_patterns import association_rules

    if time_of_day:
        
        df = df[df.time_of_day == time_of_day]
        
    if day_of_week:
        
        df = df[df.day_type == day_of_week]
        
    dummies_df = df.groupby(['Transaction', 'Item'])['Item'].count().unstack().\
                 reset_index().fillna(0).set_index('Transaction')
    
    def encode_units(x):
    
        if x <= 0:
            return 0
        if x >= 1:
            return 1
    
    dummies_df = dummies_df.applymap(encode_units)
    
    frequent_itemsets = apriori(dummies_df, min_support= min_support, use_colnames=True)

    rules = association_rules(frequent_itemsets, metric=metric, min_threshold=min_threshold)
    
    rules.drop_duplicates(subset='leverage', keep='first', inplace=True)
    rules = rules.sort_values(by='lift', ascending=False)
    
    return rules

# %%
all_day_method_2 = apriori_results_method_2()

# %%
morning_method_2 = apriori_results_method_2(time_of_day = 'morning')

# %%
morning_method_2
# Out:
#                 antecedents       consequents  antecedent support  \
# 34                  (Juice)         (Cookies)            0.031928
# 46               (Sandwich)             (Tea)            0.020960
# 64            (Tea, Coffee)            (Cake)            0.040946
# 8           (Hot chocolate)            (Cake)            0.052888
# 10                    (Tea)            (Cake)            0.107482
# 40                    (Tea)           (Juice)            0.107482
# 70  (Coffee, Hot chocolate)          (Pastry)            0.028516
# 44                    (Tea)          (Muffin)            0.107482
# 18       (Keeping It Local)          (Coffee)            0.011942
# 48                    (Tea)           (Toast)            0.107482
# 65           (Coffee, Cake)             (Tea)            0.033146
# 68         (Pastry, Coffee)   (Hot chocolate)            0.077261
# 32                 (Coffee)           (Toast)            0.514989
# 36          (Hot chocolate)       (Medialuna)            0.052888
# 28                 (Coffee)  (Spanish Brunch)            0.514989
# 58          (Coffee, Bread)           (Toast)            0.094078
# 42                 (Pastry)       (Medialuna)            0.139410
# 52          (Coffee, Bread)   (Hot chocolate)            0.094078
# 50          (Coffee, Bread)         (Cookies)            0.094078
# 69  (Pastry, Hot chocolate)          (Coffee)            0.009262
# 74         (Pastry, Coffee)       (Medialuna)            0.077261
# 54          (Coffee, Bread)       (Medialuna)            0.094078
# 38                 (Pastry)   (Hot chocolate)            0.139410
# 61       (Bread, Medialuna)          (Pastry)            0.029247
# 56          (Coffee, Bread)          (Pastry)            0.094078
# 16                 (Coffee)           (Juice)            0.514989
# 76      (Coffee, Medialuna)          (Pastry)            0.054594
# 60          (Pastry, Bread)       (Medialuna)            0.047039
# 12                 (Coffee)         (Cookies)            0.514989
# 0                  (Coffee)       (Alfajores)            0.514989
# 30                 (Coffee)          (Tiffin)            0.514989
# 20                 (Coffee)       (Medialuna)            0.514989
# 80            (Tea, Coffee)          (Pastry)            0.040946
# 24                 (Pastry)          (Coffee)            0.139410
# 26                 (Coffee)           (Scone)            0.514989
# 2                     (Jam)           (Bread)            0.019010
# 4                  (Coffee)         (Brownie)            0.514989
# 22                 (Coffee)          (Muffin)            0.514989
# 14                 (Coffee)   (Hot chocolate)            0.514989
# 6                  (Coffee)            (Cake)            0.514989
# 75      (Pastry, Medialuna)          (Coffee)            0.017304
#
#     consequent support   support  confidence      lift  leverage  conviction
# 34            0.047526  0.006093    0.190840  4.015463  0.004576    1.177114
# 62                   (Juice)         (Cookies)            0.043427
# 134            (Tea, Coffee)           (Scone)            0.057182
# 115           (Coffee, Cake)   (Hot chocolate)            0.071920
# 128           (Coffee, Soup)        (Sandwich)            0.027707
# 80                (Sandwich)        (Truffles)            0.115936
# 102          (Coffee, Bread)          (Pastry)            0.089998
# 66                (Sandwich)           (Juice)            0.115936
# 60           (Hot chocolate)         (Cookies)            0.061505
# 18           (Hot chocolate)            (Cake)            0.061505
# 122            (Tea, Coffee)            (Cake)            0.057182
# 126       (Sandwich, Coffee)            (Soup)            0.062291
# 82                     (Tea)           (Scone)            0.169778
# 86                     (Tea)  (Spanish Brunch)            0.169778
# 84                     (Tea)            (Soup)            0.169778
# 20                   (Juice)            (Cake)            0.043427
# 56                   (Toast)          (Coffee)            0.022401
# 120         (Sandwich, Cake)          (Coffee)            0.011987
# 109        (Coffee, Cookies)            (Cake)            0.027707
# 88                     (Tea)           (Toast)            0.169778
# 76                (Sandwich)            (Soup)            0.115936
# 135          (Coffee, Scone)             (Tea)            0.021222
# 26                     (Tea)    (Chicken Stew)            0.169778
# 127         (Sandwich, Soup)          (Coffee)            0.010022
# 24                     (Tea)            (Cake)            0.169778
# 92              (Tea, Bread)            (Cake)            0.033798
# 46                   (Salad)          (Coffee)            0.017489
# 116    (Hot chocolate, Cake)          (Coffee)            0.014934
# 132            (Tea, Coffee)        (Sandwich)            0.057182
# 108           (Coffee, Cake)         (Cookies)            0.071920
# 64                     (Tea)         (Cookies)            0.169778
# 110          (Cookies, Cake)          (Coffee)            0.009236
# 70                     (Tea)       (Medialuna)            0.169778
# 4                    (Bread)  (Jammie Dodgers)            0.305758
# 93             (Bread, Cake)             (Tea)            0.030458
# 44                  (Pastry)          (Coffee)            0.045785
# 52                  (Coffee)  (Spanish Brunch)            0.459815
# 32       (Hearty & Seasonal)          (Coffee)            0.017882
# 2                      (Tea)       (Alfajores)            0.169778
# 48                (Sandwich)          (Coffee)            0.115936
# 40                  (Coffee)       (Medialuna)            0.459815
# 22                   (Scone)            (Cake)            0.042051
# 12                     (Tea)         (Brownie)            0.169778
# 36                  (Coffee)  (Jammie Dodgers)            0.459815
# 106          (Coffee, Bread)        (Sandwich)            0.089998
# 16                    (Cake)         (Cookies)            0.136766
# 30                (Frittata)          (Coffee)            0.014934
# 14                  (Coffee)            (Cake)            0.459815
# 6                   (Pastry)           (Bread)            0.045785
# 54                  (Coffee)          (Tiffin)            0.459815
# 0                   (Coffee)       (Alfajores)            0.459815
# 78                (Sandwich)             (Tea)            0.115936
# 123           (Coffee, Cake)             (Tea)            0.071920
# 90           (Coffee, Bread)            (Cake)            0.089998
# 96           (Coffee, Bread)   (Hot chocolate)            0.089998
# 50                  (Coffee)           (Scone)            0.459815
# 68                     (Tea)           (Juice)            0.169778
# 8                    (Bread)          (Tiffin)            0.305758
# 101          (Pastry, Bread)          (Coffee)            0.015720
# 38                   (Juice)          (Coffee)            0.043427
# 97    (Hot chocolate, Bread)          (Coffee)            0.012380
# 34                  (Coffee)   (Hot chocolate)            0.459815
# 172            (Tea, Coffee)           (Scone)            0.052711
# 80           (Hot chocolate)          (Muffin)            0.071084
# 147           (Coffee, Cake)           (Scone)            0.059337
# 162            (Tea, Coffee)       (Medialuna)            0.052711
# 84           (Hot chocolate)           (Scone)            0.071084
# 106                    (Tea)  (Spanish Brunch)            0.130120
# 153           (Coffee, Cake)             (Tea)            0.059337
# 66                  (Coffee)  (Spanish Brunch)            0.465060
# 146          (Coffee, Scone)            (Cake)            0.031928
# 113            (Bread, Cake)             (Tea)            0.029217
# 68                  (Coffee)       (The Nomad)            0.465060
# 141         (Sandwich, Cake)          (Coffee)            0.007831
# 126          (Coffee, Bread)          (Pastry)            0.100301
# 72                  (Coffee)           (Toast)            0.465060
# 92                     (Tea)           (Juice)            0.130120
# 4                      (Tea)       (Alfajores)            0.130120
# 44       (Hearty & Seasonal)          (Coffee)            0.011446
# 116          (Coffee, Bread)         (Cookies)            0.100301
# 56                   (Salad)          (Coffee)            0.009639
# 142           (Coffee, Cake)        (Sandwich)            0.059337
# 120          (Coffee, Bread)   (Hot chocolate)            0.100301
# 0                (Alfajores)            (Cake)            0.038554
# 168            (Tea, Pastry)          (Coffee)            0.008434
# 124          (Coffee, Bread)       (Medialuna)            0.100301
# 36                   (Scone)            (Cake)            0.061145
# 163         (Tea, Medialuna)          (Coffee)            0.009940
# 30                   (Juice)            (Cake)            0.041566
# 157      (Pastry, Medialuna)          (Coffee)            0.011747
# 64                  (Coffee)            (Soup)            0.465060
# 24                 (Cookies)            (Cake)            0.040361
# 136    (Hot chocolate, Cake)          (Coffee)            0.014759
# 58                (Sandwich)          (Coffee)            0.065361
# 52                  (Coffee)       (Medialuna)            0.465060
# 132          (Coffee, Bread)           (Scone)            0.100301
# 100               (Sandwich)             (Tea)            0.065361
# 86                     (Tea)   (Hot chocolate)            0.130120
# 70                  (Coffee)          (Tiffin)            0.465060
# 50                  (Coffee)           (Juice)            0.465060
# 78           (Hot chocolate)       (Medialuna)            0.071084
# 148            (Scone, Cake)          (Coffee)            0.009940
# 169            (Tea, Coffee)          (Pastry)            0.052711
# 173          (Coffee, Scone)             (Tea)            0.031928
# 32                  (Muffin)            (Cake)            0.045482
# 96                     (Tea)          (Muffin)            0.130120
# 40                  (Coffee)         (Cookies)            0.465060
# 129          (Coffee, Bread)        (Sandwich)            0.100301
# 18                  (Coffee)         (Brownie)            0.465060
# 108          (Coffee, Bread)         (Brownie)            0.100301
# 140       (Sandwich, Coffee)            (Cake)            0.039458
# 46                  (Coffee)   (Hot chocolate)            0.465060
# 54                  (Pastry)          (Coffee)            0.083434
# 2                   (Coffee)       (Alfajores)            0.465060
# 60                  (Coffee)           (Scone)            0.465060
# 12                  (Pastry)           (Bread)            0.083434
# 82                  (Pastry)   (Hot chocolate)            0.083434
# 121   (Hot chocolate, Bread)          (Coffee)            0.019277
# 16                 (Brownie)            (Cake)            0.051807
# 8                      (Jam)           (Bread)            0.018675
# 62                  (Coffee)       (Smoothies)            0.465060
# 48                  (Coffee)  (Jammie Dodgers)            0.465060
# 10             0.018675  0.006627    0.019231  1.029777  0.000192    1.000567
# 164            0.130120  0.006325    0.133758  1.027955  0.000172    1.004199
# 42             0.465060  0.007831    0.472727  1.016486  0.000127    1.014541
# 14             0.018976  0.006627    0.019231  1.013431  0.000088    1.000260
# 34             0.118675  0.007831    0.119816  1.009614  0.000075    1.001296
# 98             0.061145  0.005120    0.061372  1.003717  0.000019    1.000242
# 6              0.344578  0.005723    0.345455  1.002543  0.000015    1.001339

# %%
weekday_method_2 = apriori_results_method_2(day_of_week = 'weekday')

# %%
weekday_method_2
# Out:
#                 antecedents       consequents  antecedent support  \
# 42               (Sandwich)            (Coke)            0.075346
# 46                  (Juice)         (Cookies)            0.036941
# 76  (Coffee, Hot chocolate)            (Cake)            0.025386
# 52               (Sandwich)           (Juice)            0.075346
# 77           (Coffee, Cake)   (Hot chocolate)            0.052238
# 12                  (Juice)            (Cake)            0.036941
# 44          (Hot chocolate)         (Cookies)            0.051424
# 60               (Sandwich)            (Soup)            0.075346
# 82            (Tea, Coffee)            (Cake)            0.048332
# 10          (Hot chocolate)            (Cake)            0.051424
# 64                    (Tea)           (Scone)            0.149390
# 66                    (Tea)            (Soup)            0.149390
# 56                 (Pastry)       (Medialuna)            0.087551
# 24       (Keeping It Local)          (Coffee)            0.007486
# 87            (Tea, Coffee)        (Sandwich)            0.048332
# 14                    (Tea)            (Cake)            0.149390
# 40                  (Toast)          (Coffee)            0.037266
# 62               (Sandwich)             (Tea)            0.075346
# 72          (Coffee, Bread)          (Pastry)            0.084459
# 4                     (Tea)         (Brownie)            0.149390
# 48                    (Tea)         (Cookies)            0.149390
# 68                    (Tea)           (Toast)            0.149390
# 8                 (Cookies)            (Cake)            0.062002
# 32                  (Salad)          (Coffee)            0.010903
# 2                     (Tea)       (Alfajores)            0.149390
# 54                    (Tea)           (Juice)            0.149390
# 78    (Hot chocolate, Cake)          (Coffee)            0.009601
# 58                    (Tea)          (Muffin)            0.149390
# 83           (Coffee, Cake)             (Tea)            0.052238
# 30                 (Pastry)          (Coffee)            0.087551
# 50                 (Pastry)   (Hot chocolate)            0.087551
# 0                  (Coffee)       (Alfajores)            0.485598
# 6                  (Coffee)            (Cake)            0.485598
# 26                 (Coffee)       (Medialuna)            0.485598
# 36                 (Coffee)           (Scone)            0.485598
# 74          (Coffee, Bread)        (Sandwich)            0.084459
# 38                 (Coffee)          (Tiffin)            0.485598
# 70          (Coffee, Bread)            (Cake)            0.084459
# 28                 (Coffee)          (Muffin)            0.485598
# 20                 (Coffee)  (Jammie Dodgers)            0.485598
# 22                 (Coffee)           (Juice)            0.485598
# 86       (Sandwich, Coffee)             (Tea)            0.037592
# 16                 (Coffee)         (Cookies)            0.485598
# 34               (Sandwich)          (Coffee)            0.075346
# 18                 (Coffee)   (Hot chocolate)            0.485598
#
#     consequent support   support  confidence      lift  leverage  conviction
# 42            0.020504  0.005696    0.075594  3.686705  0.004151    1.059594
# 46            0.062002  0.007160    0.193833  3.126250  0.004870    1.163528
# 76            0.095850  0.005696    0.224359  2.340723  0.003262    1.165681
# 91            (Coffee, Brownie)   (Hot chocolate)            0.026117
# 90      (Coffee, Hot chocolate)         (Brownie)            0.041924
# 6               (Hot chocolate)         (Brownie)            0.067354
# 110        (Coffee, Farm House)       (Medialuna)            0.014433
# 97               (Coffee, Cake)   (Hot chocolate)            0.032302
# 80              (Coffee, Bread)  (Spanish Brunch)            0.102405
# 62                        (Tea)           (Juice)            0.084536
# 107              (Coffee, Cake)             (Tea)            0.032302
# 96      (Coffee, Hot chocolate)            (Cake)            0.041924
# 122            (Pastry, Coffee)   (Hot chocolate)            0.068041
# 40                     (Coffee)       (The Nomad)            0.488660
# 12                     (Muffin)            (Cake)            0.043986
# 106               (Tea, Coffee)            (Cake)            0.039175
# 14                        (Tea)            (Cake)            0.084536
# 24           (Keeping It Local)          (Coffee)            0.007560
# 54              (Hot chocolate)          (Muffin)            0.067354
# 103           (Medialuna, Cake)          (Coffee)            0.006186
# 38                     (Coffee)  (Spanish Brunch)            0.488660
# 68                        (Tea)          (Muffin)            0.084536
# 10              (Hot chocolate)            (Cake)            0.067354
# 84              (Coffee, Bread)           (Toast)            0.102405
# 124     (Coffee, Hot chocolate)          (Pastry)            0.041924
# 74              (Coffee, Bread)       (Medialuna)            0.102405
# 98        (Hot chocolate, Cake)          (Coffee)            0.008247
# 128            (Pastry, Coffee)       (Medialuna)            0.068041
# 58              (Hot chocolate)           (Scone)            0.067354
# 16                     (Coffee)            (Coke)            0.488660
# 44                      (Toast)          (Coffee)            0.037801
# 117         (Coffee, Medialuna)   (Hot chocolate)            0.075601
# 56                     (Pastry)   (Hot chocolate)            0.137457
# 70                        (Tea)           (Scone)            0.084536
# 140               (Tea, Pastry)          (Coffee)            0.009622
# 48                 (Farm House)       (Medialuna)            0.052921
# 116     (Coffee, Hot chocolate)       (Medialuna)            0.041924
# 22                      (Juice)          (Coffee)            0.033677
# 32                   (Sandwich)          (Coffee)            0.017869
# 118  (Hot chocolate, Medialuna)          (Coffee)            0.010997
# 72              (Coffee, Bread)   (Hot chocolate)            0.102405
# 134               (Tea, Coffee)       (Medialuna)            0.039175
# 42                     (Coffee)          (Tiffin)            0.488660
# 111         (Coffee, Medialuna)      (Farm House)            0.075601
# 135            (Tea, Medialuna)          (Coffee)            0.010309
# 87           (Bread, Medialuna)          (Pastry)            0.043986
# 102              (Coffee, Cake)       (Medialuna)            0.032302
# 123     (Pastry, Hot chocolate)          (Coffee)            0.013746
# 78              (Coffee, Bread)           (Scone)            0.102405
# 46                     (Coffee)        (Truffles)            0.488660
# 64                     (Pastry)       (Medialuna)            0.137457
# 52              (Hot chocolate)       (Medialuna)            0.067354
# 141               (Tea, Coffee)          (Pastry)            0.039175
# 18                     (Coffee)         (Cookies)            0.488660
# 20                     (Coffee)   (Hot chocolate)            0.488660
# 130         (Coffee, Medialuna)          (Pastry)            0.075601
# 4                      (Coffee)         (Brownie)            0.488660
# 26                     (Coffee)       (Medialuna)            0.488660
# 76              (Coffee, Bread)          (Pastry)            0.102405
# 86              (Pastry, Bread)       (Medialuna)            0.054296
# 18            0.031344  0.018127    0.034237  1.092278  0.001531    1.002995
# 62            0.120091  0.005287    0.130841  1.089520  0.000434    1.012369
# 28            0.044940  0.006798    0.048387  1.076715  0.000484    1.003623
# 12            0.529456  0.017372    0.560976  1.059532  0.000976    1.071794
# 58            0.140483  0.006042    0.144144  1.026058  0.000153    1.004277
# 60            0.529456  0.005287    0.538462  1.017009  0.000088    1.019512

# %%
weekday_afternoon_method_2 = apriori_results_method_2(day_of_week = 'weekday', time_of_day = 'afternoon')

# %%
weekday_afternoon_method_2
# Out:
#                  antecedents       consequents  antecedent support  \
# 66           (Mineral water)        (Sandwich)            0.020752
# 50                (Sandwich)            (Coke)            0.120000
# 54                   (Juice)         (Cookies)            0.041203
# 100  (Coffee, Hot chocolate)            (Cake)            0.027970
# 101           (Coffee, Cake)   (Hot chocolate)            0.066165
# 52           (Hot chocolate)         (Cookies)            0.055038
# 60                (Sandwich)           (Juice)            0.120000
# 120           (Coffee, Soup)        (Sandwich)            0.030677
# 78                     (Tea)  (Spanish Brunch)            0.169023
# 72                (Sandwich)        (Truffles)            0.120000
# 16           (Hot chocolate)            (Cake)            0.055038
# 89           (Coffee, Bread)          (Pastry)            0.083308
# 18                   (Juice)            (Cake)            0.041203
# 110            (Tea, Coffee)            (Cake)            0.052932
# 114            (Tea, Coffee)         (Cookies)            0.052932
# 76                     (Tea)            (Soup)            0.169023
# 74                     (Tea)           (Scone)            0.169023
# 118       (Sandwich, Coffee)            (Soup)            0.061353
# 48                  (Coffee)           (Toast)            0.458045
# 124            (Tea, Coffee)        (Sandwich)            0.052932
# 10                     (Tea)         (Brownie)            0.169023
# 80                     (Tea)           (Toast)            0.169023
# 94         (Coffee, Cookies)            (Cake)            0.029474
# 107         (Sandwich, Cake)          (Coffee)            0.011729
# 38                   (Salad)          (Coffee)            0.018045
# 20                     (Tea)            (Cake)            0.169023
# 102    (Hot chocolate, Cake)          (Coffee)            0.012632
# 56                     (Tea)         (Cookies)            0.169023
# 84              (Tea, Bread)            (Cake)            0.030977
# 22                     (Tea)    (Chicken Stew)            0.169023
# 119         (Sandwich, Soup)          (Coffee)            0.011429
# 126            (Tea, Coffee)            (Soup)            0.052932
# 68                (Sandwich)            (Soup)            0.120000
# 64                     (Tea)       (Medialuna)            0.169023
# 96           (Cake, Cookies)          (Coffee)            0.009323
# 85             (Bread, Cake)             (Tea)            0.025564
# 95            (Coffee, Cake)         (Cookies)            0.066165
# 28                  (Coffee)  (Jammie Dodgers)            0.458045
# 70                     (Tea)        (Sandwich)            0.169023
# 36                  (Pastry)          (Coffee)            0.047519
# 12                  (Coffee)            (Cake)            0.458045
# 115        (Coffee, Cookies)             (Tea)            0.029474
# 92           (Coffee, Bread)        (Sandwich)            0.083308
# 0                   (Coffee)       (Alfajores)            0.458045
# 14                 (Cookies)            (Cake)            0.066165
# 40                (Sandwich)          (Coffee)            0.120000
# 42                  (Coffee)           (Scone)            0.458045
# 46                  (Coffee)          (Tiffin)            0.458045
# 26                  (Coffee)   (Hot chocolate)            0.458045
# 64             0.034586  0.007519    0.044484  1.286167  0.001673    1.010358
# 96             0.458045  0.005414    0.580645  1.267659  0.001143    1.292354
# 85             0.169023  0.005414    0.211765  1.252878  0.001093    1.054225
# 95             0.066165  0.005414    0.081818  1.236570  0.001036    1.017048
# 28             0.011128  0.006015    0.013132  1.180103  0.000918    1.002031
# 70             0.120000  0.023759    0.140569  1.171412  0.003477    1.023934
# 36             0.458045  0.025263    0.531646  1.160684  0.003497    1.157147
# 12             0.125414  0.066165    0.144452  1.151803  0.008720    1.022253
# 115            0.169023  0.005714    0.193878  1.147051  0.000733    1.030833
# 92             0.120000  0.011429    0.137184  1.143201  0.001432    1.019916
# 0              0.040602  0.021053    0.045962  1.132025  0.002455    1.005619
# 14             0.125414  0.009323    0.140909  1.123556  0.001025    1.018037
# 40             0.458045  0.061353    0.511278  1.116218  0.006388    1.108923
# 42             0.030677  0.015639    0.034143  1.112999  0.001588    1.003589
# 46             0.016541  0.008421    0.018385  1.111443  0.000844    1.001878
# 26             0.055038  0.027970    0.061064  1.109491  0.002760    1.006418
# 6              0.298346  0.015639    0.329114  1.103129  0.001462    1.045862
# 8              0.016541  0.005414    0.018145  1.096957  0.000478    1.001633
# 4              0.040602  0.007519    0.044484  1.095624  0.000656    1.004063
# 32             0.034586  0.017143    0.037426  1.082103  0.001301    1.002950
# 34             0.036692  0.017744    0.038739  1.055806  0.000938    1.002130
# 24             0.458045  0.008722    0.483333  1.055209  0.000456    1.048945
# 2              0.040602  0.005113    0.042607  1.049383  0.000241    1.002094
# 111            0.169023  0.011729    0.177273  1.048811  0.000546    1.010028
# 62             0.041203  0.007218    0.042705  1.036444  0.000254    1.001569
# 82             0.125414  0.010827    0.129964  1.036283  0.000379    1.005230
# 30             0.041203  0.019549    0.042679  1.035821  0.000676    1.001542
# 44             0.017143  0.008120    0.017728  1.034143  0.000268    1.000596
# 106            0.125414  0.007820    0.127451  1.016246  0.000125    1.002335
# 88             0.458045  0.007218    0.461538  1.007627  0.000055    1.006488
# 58             0.055038  0.006617    0.055138  1.001821  0.000012    1.000106

# %%
weekday_afternoon_method_2.groupby(by='antecedents')['lift'].sum().sort_values(ascending=False)
# Out:
# antecedents
# (Tea)                      16.837318
# (Coffee)                   12.533971
# (Sandwich)                 10.925505
# (Tea, Coffee)               6.229868
# (Coffee, Cake)              4.515262
# (Juice)                     4.231257
# (Coffee, Bread)             4.002817
# (Hot chocolate)             3.729539
# (Mineral water)             2.777778
# (Coffee, Cookies)           2.611594
# (Sandwich, Coffee)          2.552629
# (Coffee, Hot chocolate)     2.314922
# (Pastry)                    2.263813
# (Coffee, Soup)              1.879085
# (Sandwich, Cake)            1.455461
# (Salad)                     1.419074
# (Hot chocolate, Cake)       1.403480
# (Tea, Bread)                1.393448
# (Sandwich, Soup)            1.321405
# (Cake, Cookies)             1.267659
# (Bread, Cake)               1.252878
# (Cookies)                   1.123556
# (Bread)                     1.096957
# (Hearty & Seasonal)         1.055209
# (Pastry, Bread)             1.007627
# Name: lift, dtype: float64
